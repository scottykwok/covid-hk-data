# %% [markdown]
# # Part 1 - Analysis Current Snapshot

# %%
import pandas as pd
import numpy as np
import datetime
import requests
import urllib.request
import time
import os
import math
from pathlib import Path
### Set TimeZone to HK if you are using docker container
#!rm /etc/localtime
#!ln -s /usr/share/zoneinfo/Asia/Hong_Kong /etc/localtime

# %% [markdown]
# ### Load data from 資料一線通 (data.gov.hk)

# %% [markdown]
# The data source is "2019冠狀病毒病的本地最新情況(繁體中文)" / "Latest local situation of COVID-19 (Traditional Chinese)".
#
# https://data.gov.hk/en-data/dataset/hk-dh-chpsebcddr-novel-infectious-agent/resource/3ab0040c-4272-4b9a-92bc-2a44b70fd3a4
#
# The schema has changed over time, so there are at least two different schema

# %% [markdown]
# ### Old schema (v1)

# %%
s = 'http://www.chp.gov.hk/files/misc/enhanced_sur_covid_19_chi.csv&amp;time=20200404-0917'
resource_url = f'https://api.data.gov.hk/v1/historical-archive/get-file?url={s}'
df_v1 = pd.read_csv(resource_url)
df_v1[-5:]
# Out:
#      個案編號        報告日期        發病日期 性別  年齡   入住醫院名稱 住院/出院/死亡 香港/非香港居民  \
# 841   842  03/04/2020  02/04/2020  男  20     北區醫院       住院     香港居民
# 842   843  03/04/2020  02/04/2020  女  19  威爾斯親王醫院       住院     香港居民
# 843   844  03/04/2020  02/04/2020  女  59  威爾斯親王醫院       住院     香港居民
# 844   845  03/04/2020  31/03/2020  女  47   伊利沙伯醫院       住院     香港居民
# 845   846  03/04/2020  24/03/2020  男  51       待定      待入院     香港居民
#
#           個案分類* 確診/疑似個案
# 841  本地個案的密切接觸者      確診
# 842        輸入個案      確診
# 843  本地個案的密切接觸者      確診
# 844        輸入個案      確診
# 845  本地個案的密切接觸者      確診

# %% [markdown]
# ### Latest schema (v2)

# %% [markdown]
# Note the last two columns definition have been changed

# %%
# Get the latest data
resource_url = 'http://www.chp.gov.hk/files/misc/enhanced_sur_covid_19_chi.csv'
df_v2 = pd.read_csv(resource_url)
df_v2[-5:]
# Out:
#         個案編號        報告日期 發病日期  性別  年齡  入住醫院名稱 住院/出院/死亡 香港/非香港居民     分類* 個案狀況*
# 15436  97093  06/02/2022   待定  待定  待定     NaN      待入院       待定  本地感染個案    待定
# 15437  97094  06/02/2022   待定  待定  待定     NaN      待入院       待定  本地感染個案    待定
# 15438  97095  06/02/2022   待定  待定  待定     NaN      待入院       待定  本地感染個案    待定
# 15439  97096  06/02/2022   待定   女  72     NaN      待入院       待定  本地感染個案    待定
# 15440  97097  06/02/2022   待定   女  11     NaN      待入院       待定  本地感染個案    待定

# %% [markdown]
# ### Notice the severe delay 數據更新嚴重滯後

# %% [markdown]
# Although the datasource was claimed to update every night, we can see a very severe delay in the data report dates.  For examples, on the 8 Mar 2022, the API only return the patient list upto 6 Feb 2022 !
#
# <strong> A total of 4 weeks delay !🤯 </strong>
#
# <strong>有數據但係delay四個星期! 🤯 </strong>

# %% [markdown]
# ## Lets inspect the unique values in each column

# %%
PREVIEW_COLS = ['性別','年齡','入住醫院名稱','住院/出院/死亡','香港/非香港居民','分類*','個案狀況*','個案分類*','確診/疑似個案']
def preview(df):
    print('-' * 20, "Columns", '-'* 20)
    print("columns", ":\n", list(df.columns.values))

    print('-' * 20, "Distinct Values", '-'* 20)
    for col in PREVIEW_COLS:
        if col in df.columns.values:
            print(col, ":\n" , df[col].unique())
    
    print('-' * 20, "Dates Example", '-'* 20)
    for col in df[['報告日期', '發病日期']]:
        print(col, ":\n" , df[col][0:5].values)
        
#preview(df_v1)
preview(df_v2)
# Out:
# -------------------- Columns --------------------
# columns :
#  ['個案編號', '報告日期', '發病日期', '性別', '年齡', '入住醫院名稱', '住院/出院/死亡', '香港/非香港居民', '分類*', '個案狀況*']
# -------------------- Distinct Values --------------------
# 性別 :
#  ['男' '女' nan '待定']
# 年齡 :
#  ['39' '56' '62' '63' '47' '68' '64' '73' '72' '37' '75' '80' '60' '25'
#  '28' '55' '65' '58' '42' '24' '70' '91' '57' '22' '50' '51' '23' '69'
#  '86' '52' '59' '71' '66' '43' '67' '41' '61' '54' '45' '46' '32' '83'
#  '38' '48' '96' '76' '35' '33' '49' '21' '16' '29' '26' '89' '79' '84'
#  '44' '36' '31' '1' '30' '18' '27' '34' '20' '12' '19' '40' '4' '13' '17'
#  '15' '11' '74' '78' '7' '14' '77' '53' '<1' '2' '93' '6' '3' '8' '5' '10'
#  '9' '85' '92' '95' '87' '90' '94' '82' '88' '81' '97' '100' '98' nan '待定']
# 入住醫院名稱 :
#  [nan]
# 住院/出院/死亡 :
#  ['出院' '死亡' '不適用' nan '住院' '待入院']
# 香港/非香港居民 :
#  ['非香港居民' '香港居民' nan '待定']
# 分類* :
#  ['輸入個案' '與輸入個案有流行病學關連' '可能本地個案' '本地個案' '與本地個案有流行病學關連' '與可能本地個案有流行病學關連' nan
#  '本地感染個案']
# 個案狀況* :
#  ['確診' '删除' '無症狀感染' '復陽' '待定' '未知']
# -------------------- Dates Example --------------------
# 報告日期 :
#  ['23/01/2020' '23/01/2020' '24/01/2020' '24/01/2020' '24/01/2020']
# 發病日期 :
#  ['21/01/2020' '18/01/2020' '20/01/2020' '23/01/2020' '23/01/2020']

# %% [markdown]
# ## Data cleansing

# %% [markdown]
# There are quite some inconsistent values/typos we need to clean.
# Here is a quick & dirty cleaning by mapping all invalid values to NaN.
# I also simplified the import/local cases category.

# %%
# Parse date
def parse_ddmmYYYY(s):
    try:
        if isinstance(s, str):
            if s in ['無病徵','不適用','未知', '一月','三月中','七月中','十月' , 'Unknown']:
                return np.NaN
            else:
                return datetime.datetime.strptime(s,'%d/%m/%Y')
        else:
            return np.NaN
    except:
        print(f"****** Failed to parse ddmmYYY: {s}, type={type(s)} ******")
        return np.NaN

# Parse Age
def parse_age(s):
    try:
        if isinstance(s, str):
            if s == '<1' or '個月' in s:
                return float(0)
            elif s in ['不適用', 'pending']:
                return np.NaN
            else:
                return float(s)
        elif math.isnan(s):
            return np.NaN
        else:
            return float(s)
    except:
        print(f"****** Failed to parse Age: {s}, type={type(s)} ******")
        return np.NaN

# Parse Category
def parse_category(s):
    if isinstance(s, str):
        if '輸入個案' in s:
            return '輸入個案'
        elif '本地' in s:
            return '本地個案'
        else:
            return s
    else:
        return np.NaN

# Clean the data
def cleanse(df):
    df = df.copy()
    
    # Map V1 to V2 cols
    if '個案分類*' in df.columns.values:
        df.rename(columns={'個案分類*':'分類*'}, inplace=True)
    if '確診/疑似個案' in df.columns.values:
        df.rename(columns={'確診/疑似個案':'個案狀況*'}, inplace=True)
    
    # Parsing and Defaults
    df = df.replace(['待定'], np.NaN)
    df['年齡'] = df['年齡'].apply(parse_age)    
    df['發病日期'] = df['發病日期'].apply(parse_ddmmYYYY)
    df['報告日期'] = df['報告日期'].apply(parse_ddmmYYYY)
    df['分類*'] = df['分類*'].apply(parse_category)
    
    # Compute
    try:
        df['報告與發病日差'] = (df['報告日期'] - df['發病日期']).dt.days
    except:
        print(f"**Failed to compute 報告與發病日差")
        df['報告與發病日差'] = np.NaN
    return df

df = cleanse(df_v2)

# %% [markdown]
# ## Statistics

# %% [markdown]
# Now we can play around with different grouping statistics. For examples:

# %% [markdown]
# ### Total Count and Average Age of each category

# %%
from IPython.display import display

display(
    df.groupby(
        ['分類*', '住院/出院/死亡', '個案狀況*'] #'性別'
    ).agg({
        '性別': ['count'],
        '年齡': ['mean']
    }).round(1).replace(np.NaN, '-')
)
print("From ", min(df['報告日期']), " to ", max(df['報告日期']))
# Out:
#                         性別    年齡
#                      count  mean
# 分類*  住院/出院/死亡 個案狀況*
# 本地個案 住院       無症狀感染     82  48.4
#               確診       816  45.0
#      出院       復陽         1  29.0
#               無症狀感染    149  37.2
#               確診     10103  45.2
#      待入院      無症狀感染     28  35.7
#               確診       117  37.9
#      死亡       確診       207  78.5
# 輸入個案 不適用      確診        36  37.8
#      住院       無症狀感染     22  42.2
#               確診        24  38.1
#      出院       復陽         9  30.9
#               無症狀感染    240  36.3
#               確診      3552  34.8
#      待入院      未知         1  41.0
#               無症狀感染      6  40.8
#      死亡       確診         6  60.7
# From  2020-01-23 00:00:00  to  2022-02-06 00:00:00

# %% [markdown]
# ### 第一至第四波疫情死亡人數共213人

# %%
start_date = '2019-01-01'
end_date = '2021-12-31'

display(
    df.where(
       (df['報告日期'] >= start_date) & (df['報告日期'] < end_date)
    ).groupby(
        ['住院/出院/死亡']
    ).agg({
        '性別': ['count'],
        '年齡': ['mean']
    }).round(1).replace(np.NaN, '-')
)
# Out:
#              性別    年齡
#           count  mean
# 住院/出院/死亡
# 不適用          36  37.8
# 出院        12382  43.1
# 死亡          213  78.0

# %% [markdown]
# ### 核對一下衞生署衞生防護中心資料:
#
# 截至2022年3月7日，衞生署衞生防護中心累計報告2287宗死亡個案。香港在2021年12月下旬開始出現第五波疫情，自第五波疫情起，共錄得2074宗死亡個案。因此第一至第四波疫情死亡人數是 2287 - 2074 = 213. So our code seems correct !

# %% [markdown]
# <br>
#
# #  Part 2 - Estimate hospitalized time and waiting time 住院日數及等候時間

# %% [markdown]
# 來看更複雜的細節，我地可以分析每位患者的時間線，估算患者的：
# - 等待入院日數
# - 住院日數
#
# 例如:  待入院 => 住院 => 出院
# 中間的時間相差應該就是 "等待入院日數" 及 "住院日數"
#
# Now we come to a more sophisticated analysis: tracking the timeline of each patient. The goal is to estimate:
# - the waiting time to admit to hospital
# - the staying time inside the hosptial

# %% [markdown]
# ### STEP1:  download all historical snapshot CSV to local

# %% [markdown]
# <strong>This steps can take a long time.</strong>
# And it seems wget is having a better performance than python. So the code below will generate a shell script full of wget commands, then run the script itself.

# %%
# To reduce network bandwidth, we download once and save locally
data_dir = './raw'
resource_name = 'enhanced_sur_covid_19_chi.csv'
resource_url = f'http://www.chp.gov.hk/files/misc/{resource_name}'

YESTERDAY = datetime.datetime.now() - datetime.timedelta(1)
DAY_1 = datetime.date(2020,1,1)
DAY_N = datetime.date(2024,1,1)

os.makedirs(data_dir, exist_ok=True)

def get_historical_timestamps(resource_url, start_date, end_date):
    start = start_date.strftime('%Y%m%d')
    end = end_date.strftime('%Y%m%d')
    query = f"https://api.data.gov.hk/v1/historical-archive/list-file-versions?url={resource_url}&amp;start={start}&amp;end={end}"
    j = requests.get(query).json()
    return dict(zip(j['data-dictionary-dates'],j['timestamps']))

def generate_download_script():
    os.makedirs(data_dir, exist_ok=True)
    download_script = open(Path(data_dir,"download.sh"), "w")
    timestamps = get_historical_timestamps(resource_url, DAY_1, YESTERDAY)
    download_script.write('#!/bin/sh\n')
    for yyyymmdd, file_timestamp in timestamps.items():
        query = f"https://api.data.gov.hk/v1/historical-archive/get-file?url={resource_url}&amp;time={file_timestamp}"
        output_file = f'{resource_name}_{yyyymmdd}'
        download_script.write(f"if [ ! -f {output_file} ]; then \n")
        download_script.write(f'   echo Downloading "{output_file}" from "{query}" \n')
        download_script.write(f'   wget "{query}" -q -O "{output_file}" \n')
        download_script.write(f"fi\n")
        #urllib.request.urlretrieve(query, f'{resource_name}_{yyyymmdd}')
    print("Generated:", download_script)
    download_script.close()

# Kick off the download
generate_download_script()
os.system(f"cd {data_dir}; sh ./download.sh")
# Out:
# Generated: <_io.TextIOWrapper name='raw/download.sh' mode='w' encoding='UTF-8'>
# Downloading enhanced_sur_covid_19_chi.csv_20220222 from https://api.data.gov.hk/v1/historical-archive/get-file?url=http://www.chp.gov.hk/files/misc/enhanced_sur_covid_19_chi.csv&amp;time=20220309-0952
# Downloading enhanced_sur_covid_19_chi.csv_20220223 from https://api.data.gov.hk/v1/historical-archive/get-file?url=http://www.chp.gov.hk/files/misc/enhanced_sur_covid_19_chi.csv&amp;time=20220312-0937
# 0

# %% [markdown]
# ### STEP2: Read all CSV into dataframe, cleanse them and stack them together

# %% [markdown]
# <strong>This steps can take a long time.</strong>

# %%
def concate_history():
    history = None
    for i, date in enumerate(pd.date_range(DAY_1, YESTERDAY)):
        cached_df = Path(data_dir, f"{resource_name}_{date.strftime('%Y%m%d')}_cleansed")
        if cached_df.exists():
            print(f"Processing {date}  ... cached:", cached_df)
            df = pd.read_pickle(cached_df)
        else:
            print(f"Processing {date}  ...")
            cached_csv = Path(data_dir, f"{resource_name}_{date.strftime('%Y%m%d')}")
            if not cached_csv.exists():
                #print(f"Warning: {cached_csv} is missing")
                continue
            df = pd.read_csv(cached_csv)
            df = cleanse(df)
            df.to_pickle(cached_df)
        # day1
        if history is None:
            history = df
        # Concate
        df['record_date'] = date
        history = history.append(df)
    return history

history = concate_history()
# Out:
# Processing 2020-01-01 00:00:00  ...
# Processing 2020-01-02 00:00:00  ...
# Processing 2020-01-03 00:00:00  ...
# Processing 2020-01-04 00:00:00  ...
# Processing 2020-01-05 00:00:00  ...
# Processing 2020-01-06 00:00:00  ...
# Processing 2020-01-07 00:00:00  ...
# Processing 2020-01-08 00:00:00  ...
# Processing 2020-01-09 00:00:00  ...
# Processing 2020-01-10 00:00:00  ...
# Processing 2020-01-11 00:00:00  ...
# Processing 2020-01-12 00:00:00  ...
# Processing 2020-01-13 00:00:00  ...
# Processing 2020-01-14 00:00:00  ...
# Processing 2020-01-15 00:00:00  ...
# Processing 2020-01-16 00:00:00  ...
# Processing 2020-01-17 00:00:00  ...
# Processing 2020-01-18 00:00:00  ...
# Processing 2020-01-19 00:00:00  ...
# Processing 2020-01-20 00:00:00  ...
# Processing 2020-01-21 00:00:00  ...
# Processing 2020-01-22 00:00:00  ...
# Processing 2020-01-23 00:00:00  ...
# Processing 2020-01-24 00:00:00  ...
# Processing 2020-01-25 00:00:00  ...
# Processing 2020-01-26 00:00:00  ...
# Processing 2020-01-27 00:00:00  ...
# Processing 2020-01-28 00:00:00  ...
# Processing 2020-01-29 00:00:00  ...
# Processing 2020-01-30 00:00:00  ...
# Processing 2020-01-31 00:00:00  ...
# Processing 2020-02-01 00:00:00  ...
# Processing 2020-02-02 00:00:00  ...
# Processing 2020-02-03 00:00:00  ...
# Processing 2020-02-04 00:00:00  ...
# Processing 2020-02-05 00:00:00  ...
# Processing 2020-02-06 00:00:00  ...
# Processing 2020-02-07 00:00:00  ...
# Processing 2020-02-08 00:00:00  ...
# Processing 2020-02-09 00:00:00  ...
# Processing 2020-02-10 00:00:00  ...
# Processing 2020-02-11 00:00:00  ...
# Processing 2020-02-12 00:00:00  ...
# Processing 2020-02-13 00:00:00  ...
# Processing 2020-02-14 00:00:00  ...
# Processing 2020-02-15 00:00:00  ...
# Processing 2020-02-16 00:00:00  ...
# Processing 2020-02-17 00:00:00  ...
# Processing 2020-02-18 00:00:00  ...
# Processing 2020-02-19 00:00:00  ...
# Processing 2020-02-20 00:00:00  ...
# Processing 2020-02-21 00:00:00  ...
# Processing 2020-02-22 00:00:00  ...
# Processing 2020-02-23 00:00:00  ...
# Processing 2020-02-24 00:00:00  ...
# Processing 2020-02-25 00:00:00  ...
# Processing 2020-02-26 00:00:00  ...
# Processing 2020-02-27 00:00:00  ...
# Processing 2020-02-28 00:00:00  ...
# Processing 2020-02-29 00:00:00  ...
# Processing 2020-03-01 00:00:00  ...
# Processing 2020-03-02 00:00:00  ...
# Processing 2020-03-03 00:00:00  ...
# Processing 2020-03-04 00:00:00  ...
# Processing 2020-03-05 00:00:00  ...
# Processing 2020-03-06 00:00:00  ...
# Processing 2020-03-07 00:00:00  ...
# Processing 2020-03-08 00:00:00  ...
# Processing 2020-03-09 00:00:00  ...
# Processing 2020-03-10 00:00:00  ...
# Processing 2020-03-11 00:00:00  ...
# Processing 2020-03-12 00:00:00  ...
# Processing 2020-03-13 00:00:00  ...
# Processing 2020-03-14 00:00:00  ...
# Processing 2020-03-15 00:00:00  ...
# Processing 2020-03-16 00:00:00  ...
# Processing 2020-03-17 00:00:00  ...
# Processing 2020-03-18 00:00:00  ...
# Processing 2020-03-19 00:00:00  ...
# Processing 2020-03-20 00:00:00  ...
# Processing 2020-03-21 00:00:00  ...
# Processing 2020-03-22 00:00:00  ...
# Processing 2020-03-23 00:00:00  ...
# Processing 2020-03-24 00:00:00  ...
# Processing 2020-03-25 00:00:00  ...
# Processing 2020-03-26 00:00:00  ...
# Processing 2020-03-27 00:00:00  ...
# Processing 2020-03-28 00:00:00  ...
# Processing 2020-03-29 00:00:00  ...
# Processing 2020-03-30 00:00:00  ...
# Processing 2020-03-31 00:00:00  ...
# Processing 2020-04-01 00:00:00  ...
# Processing 2020-04-02 00:00:00  ...
# Processing 2020-04-03 00:00:00  ...
# Processing 2020-04-04 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200404_cleansed
# Processing 2020-04-05 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200405_cleansed
# Processing 2020-04-06 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200406_cleansed
# Processing 2020-04-07 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200407_cleansed
# Processing 2020-04-08 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200408_cleansed
# Processing 2020-04-09 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200409_cleansed
# Processing 2020-04-10 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200410_cleansed
# Processing 2020-04-11 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200411_cleansed
# Processing 2020-04-12 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200412_cleansed
# Processing 2020-04-13 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200413_cleansed
# Processing 2020-04-14 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200414_cleansed
# Processing 2020-04-15 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200415_cleansed
# Processing 2020-04-16 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200416_cleansed
# Processing 2020-04-17 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200417_cleansed
# Processing 2020-04-18 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200418_cleansed
# Processing 2020-04-19 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200419_cleansed
# Processing 2020-04-20 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200420_cleansed
# Processing 2020-04-21 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200421_cleansed
# Processing 2020-04-22 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200422_cleansed
# Processing 2020-04-23 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200423_cleansed
# Processing 2020-04-24 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200424_cleansed
# Processing 2020-04-25 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200425_cleansed
# Processing 2020-04-26 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200426_cleansed
# Processing 2020-04-27 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200427_cleansed
# Processing 2020-04-28 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200428_cleansed
# Processing 2020-04-29 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200429_cleansed
# Processing 2020-04-30 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200430_cleansed
# Processing 2020-05-01 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200501_cleansed
# Processing 2020-05-02 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200502_cleansed
# Processing 2020-05-03 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200503_cleansed
# Processing 2020-05-04 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200504_cleansed
# Processing 2020-05-05 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200505_cleansed
# Processing 2020-05-06 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200506_cleansed
# Processing 2020-05-07 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200507_cleansed
# Processing 2020-05-08 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200508_cleansed
# Processing 2020-05-09 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200509_cleansed
# Processing 2020-05-10 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200510_cleansed
# Processing 2020-05-11 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200511_cleansed
# Processing 2020-05-12 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200512_cleansed
# Processing 2020-05-13 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200513_cleansed
# Processing 2020-05-14 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200514_cleansed
# Processing 2020-05-15 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200515_cleansed
# Processing 2020-05-16 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200516_cleansed
# Processing 2020-05-17 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200517_cleansed
# Processing 2020-05-18 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200518_cleansed
# Processing 2020-05-19 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200519_cleansed
# Processing 2020-05-20 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200520_cleansed
# Processing 2020-05-21 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200521_cleansed
# Processing 2020-05-22 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200522_cleansed
# Processing 2020-05-23 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200523_cleansed
# Processing 2020-05-24 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200524_cleansed
# Processing 2020-05-25 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200525_cleansed
# Processing 2020-05-26 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200526_cleansed
# Processing 2020-05-27 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200527_cleansed
# Processing 2020-05-28 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200528_cleansed
# Processing 2020-05-29 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200529_cleansed
# Processing 2020-05-30 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200530_cleansed
# Processing 2020-05-31 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200531_cleansed
# Processing 2020-06-01 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200601_cleansed
# Processing 2020-06-02 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200602_cleansed
# Processing 2020-06-03 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200603_cleansed
# Processing 2020-06-04 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200604_cleansed
# Processing 2020-06-05 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200605_cleansed
# Processing 2020-06-06 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200606_cleansed
# Processing 2020-06-07 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200607_cleansed
# Processing 2020-06-08 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200608_cleansed
# Processing 2020-06-09 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200609_cleansed
# Processing 2020-06-10 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200610_cleansed
# Processing 2020-06-11 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200611_cleansed
# Processing 2020-06-12 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200612_cleansed
# Processing 2020-06-13 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200613_cleansed
# Processing 2020-06-14 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200614_cleansed
# Processing 2020-06-15 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200615_cleansed
# Processing 2020-06-16 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200616_cleansed
# Processing 2020-06-17 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200617_cleansed
# Processing 2020-06-18 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200618_cleansed
# Processing 2020-06-19 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200619_cleansed
# Processing 2020-06-20 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200620_cleansed
# Processing 2020-06-21 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200621_cleansed
# Processing 2020-06-22 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200622_cleansed
# Processing 2020-06-23 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200623_cleansed
# Processing 2020-06-24 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200624_cleansed
# Processing 2020-06-25 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200625_cleansed
# Processing 2020-06-26 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200626_cleansed
# Processing 2020-06-27 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200627_cleansed
# Processing 2020-06-28 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200628_cleansed
# Processing 2020-06-29 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200629_cleansed
# Processing 2020-06-30 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200630_cleansed
# Processing 2020-07-01 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200701_cleansed
# Processing 2020-07-02 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200702_cleansed
# Processing 2020-07-03 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200703_cleansed
# Processing 2020-07-04 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200704_cleansed
# Processing 2020-07-05 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200705_cleansed
# Processing 2020-07-06 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200706_cleansed
# Processing 2020-07-07 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200707_cleansed
# Processing 2020-07-08 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200708_cleansed
# Processing 2020-07-09 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200709_cleansed
# Processing 2020-07-10 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200710_cleansed
# Processing 2020-07-11 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200711_cleansed
# Processing 2020-07-12 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200712_cleansed
# Processing 2020-07-13 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200713_cleansed
# Processing 2020-07-14 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200714_cleansed
# Processing 2020-07-15 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200715_cleansed
# Processing 2020-07-16 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200716_cleansed
# Processing 2020-07-17 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200717_cleansed
# Processing 2020-07-18 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200718_cleansed
# Processing 2020-07-19 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200719_cleansed
# Processing 2020-07-20 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200720_cleansed
# Processing 2020-07-21 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200721_cleansed
# Processing 2020-07-22 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200722_cleansed
# Processing 2020-07-23 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200723_cleansed
# Processing 2020-07-24 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200724_cleansed
# Processing 2020-07-25 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200725_cleansed
# Processing 2020-07-26 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200726_cleansed
# Processing 2020-07-27 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200727_cleansed
# Processing 2020-07-28 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200728_cleansed
# Processing 2020-07-29 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200729_cleansed
# Processing 2020-07-30 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200730_cleansed
# Processing 2020-07-31 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200731_cleansed
# Processing 2020-08-01 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200801_cleansed
# Processing 2020-08-02 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200802_cleansed
# Processing 2020-08-03 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200803_cleansed
# Processing 2020-08-04 00:00:00  ...
# Processing 2020-08-05 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200805_cleansed
# Processing 2020-08-06 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200806_cleansed
# Processing 2020-08-07 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200807_cleansed
# Processing 2020-08-08 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200808_cleansed
# Processing 2020-08-09 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200809_cleansed
# Processing 2020-08-10 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200810_cleansed
# Processing 2020-08-11 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200811_cleansed
# Processing 2020-08-12 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200812_cleansed
# Processing 2020-08-13 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200813_cleansed
# Processing 2020-08-14 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200814_cleansed
# Processing 2020-08-15 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200815_cleansed
# Processing 2020-08-16 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200816_cleansed
# Processing 2020-08-17 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200817_cleansed
# Processing 2020-08-18 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200818_cleansed
# Processing 2020-08-19 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200819_cleansed
# Processing 2020-08-20 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200820_cleansed
# Processing 2020-08-21 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200821_cleansed
# Processing 2020-08-22 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200822_cleansed
# Processing 2020-08-23 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200823_cleansed
# Processing 2020-08-24 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200824_cleansed
# Processing 2020-08-25 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200825_cleansed
# Processing 2020-08-26 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200826_cleansed
# Processing 2020-08-27 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200827_cleansed
# Processing 2020-08-28 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200828_cleansed
# Processing 2020-08-29 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200829_cleansed
# Processing 2020-08-30 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200830_cleansed
# Processing 2020-08-31 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200831_cleansed
# Processing 2020-09-01 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200901_cleansed
# Processing 2020-09-02 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200902_cleansed
# Processing 2020-09-03 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200903_cleansed
# Processing 2020-09-04 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200904_cleansed
# Processing 2020-09-05 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200905_cleansed
# Processing 2020-09-06 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200906_cleansed
# Processing 2020-09-07 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200907_cleansed
# Processing 2020-09-08 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200908_cleansed
# Processing 2020-09-09 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200909_cleansed
# Processing 2020-09-10 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200910_cleansed
# Processing 2020-09-11 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200911_cleansed
# Processing 2020-09-12 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200912_cleansed
# Processing 2020-09-13 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200913_cleansed
# Processing 2020-09-14 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200914_cleansed
# Processing 2020-09-15 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200915_cleansed
# Processing 2020-09-16 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200916_cleansed
# Processing 2020-09-17 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200917_cleansed
# Processing 2020-09-18 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200918_cleansed
# Processing 2020-09-19 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200919_cleansed
# Processing 2020-09-20 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200920_cleansed
# Processing 2020-09-21 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200921_cleansed
# Processing 2020-09-22 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200922_cleansed
# Processing 2020-09-23 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200923_cleansed
# Processing 2020-09-24 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200924_cleansed
# Processing 2020-09-25 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200925_cleansed
# Processing 2020-09-26 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200926_cleansed
# Processing 2020-09-27 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200927_cleansed
# Processing 2020-09-28 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200928_cleansed
# Processing 2020-09-29 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200929_cleansed
# Processing 2020-09-30 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20200930_cleansed
# Processing 2020-10-01 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201001_cleansed
# Processing 2020-10-02 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201002_cleansed
# Processing 2020-10-03 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201003_cleansed
# Processing 2020-10-04 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201004_cleansed
# Processing 2020-10-05 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201005_cleansed
# Processing 2020-10-06 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201006_cleansed
# Processing 2020-10-07 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201007_cleansed
# Processing 2020-10-08 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201008_cleansed
# Processing 2020-10-09 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201009_cleansed
# Processing 2020-10-10 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201010_cleansed
# Processing 2020-10-11 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201011_cleansed
# Processing 2020-10-12 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201012_cleansed
# Processing 2020-10-13 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201013_cleansed
# Processing 2020-10-14 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201014_cleansed
# Processing 2020-10-15 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201015_cleansed
# Processing 2020-10-16 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201016_cleansed
# Processing 2020-10-17 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201017_cleansed
# Processing 2020-10-18 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201018_cleansed
# Processing 2020-10-19 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201019_cleansed
# Processing 2020-10-20 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201020_cleansed
# Processing 2020-10-21 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201021_cleansed
# Processing 2020-10-22 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201022_cleansed
# Processing 2020-10-23 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201023_cleansed
# Processing 2020-10-24 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201024_cleansed
# Processing 2020-10-25 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201025_cleansed
# Processing 2020-10-26 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201026_cleansed
# Processing 2020-10-27 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201027_cleansed
# Processing 2020-10-28 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201028_cleansed
# Processing 2020-10-29 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201029_cleansed
# Processing 2020-10-30 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201030_cleansed
# Processing 2020-10-31 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201031_cleansed
# Processing 2020-11-01 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201101_cleansed
# Processing 2020-11-02 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201102_cleansed
# Processing 2020-11-03 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201103_cleansed
# Processing 2020-11-04 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201104_cleansed
# Processing 2020-11-05 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201105_cleansed
# Processing 2020-11-06 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201106_cleansed
# Processing 2020-11-07 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201107_cleansed
# Processing 2020-11-08 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201108_cleansed
# Processing 2020-11-09 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201109_cleansed
# Processing 2020-11-10 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201110_cleansed
# Processing 2020-11-11 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201111_cleansed
# Processing 2020-11-12 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201112_cleansed
# Processing 2020-11-13 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201113_cleansed
# Processing 2020-11-14 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201114_cleansed
# Processing 2020-11-15 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201115_cleansed
# Processing 2020-11-16 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201116_cleansed
# Processing 2020-11-17 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201117_cleansed
# Processing 2020-11-18 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201118_cleansed
# Processing 2020-11-19 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201119_cleansed
# Processing 2020-11-20 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201120_cleansed
# Processing 2020-11-21 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201121_cleansed
# Processing 2020-11-22 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201122_cleansed
# Processing 2020-11-23 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201123_cleansed
# Processing 2020-11-24 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201124_cleansed
# Processing 2020-11-25 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201125_cleansed
# Processing 2020-11-26 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201126_cleansed
# Processing 2020-11-27 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201127_cleansed
# Processing 2020-11-28 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201128_cleansed
# Processing 2020-11-29 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201129_cleansed
# Processing 2020-11-30 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201130_cleansed
# Processing 2020-12-01 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201201_cleansed
# Processing 2020-12-02 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201202_cleansed
# Processing 2020-12-03 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201203_cleansed
# Processing 2020-12-04 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201204_cleansed
# Processing 2020-12-05 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201205_cleansed
# Processing 2020-12-06 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201206_cleansed
# Processing 2020-12-07 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201207_cleansed
# Processing 2020-12-08 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201208_cleansed
# Processing 2020-12-09 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201209_cleansed
# Processing 2020-12-10 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201210_cleansed
# Processing 2020-12-11 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201211_cleansed
# Processing 2020-12-12 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201212_cleansed
# Processing 2020-12-13 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201213_cleansed
# Processing 2020-12-14 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201214_cleansed
# Processing 2020-12-15 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201215_cleansed
# Processing 2020-12-16 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201216_cleansed
# Processing 2020-12-17 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201217_cleansed
# Processing 2020-12-18 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201218_cleansed
# Processing 2020-12-19 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201219_cleansed
# Processing 2020-12-20 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201220_cleansed
# Processing 2020-12-21 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201221_cleansed
# Processing 2020-12-22 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201222_cleansed
# Processing 2020-12-23 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201223_cleansed
# Processing 2020-12-24 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201224_cleansed
# Processing 2020-12-25 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201225_cleansed
# Processing 2020-12-26 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201226_cleansed
# Processing 2020-12-27 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201227_cleansed
# Processing 2020-12-28 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201228_cleansed
# Processing 2020-12-29 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201229_cleansed
# Processing 2020-12-30 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201230_cleansed
# Processing 2020-12-31 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20201231_cleansed
# Processing 2021-01-01 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210101_cleansed
# Processing 2021-01-02 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210102_cleansed
# Processing 2021-01-03 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210103_cleansed
# Processing 2021-01-04 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210104_cleansed
# Processing 2021-01-05 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210105_cleansed
# Processing 2021-01-06 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210106_cleansed
# Processing 2021-01-07 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210107_cleansed
# Processing 2021-01-08 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210108_cleansed
# Processing 2021-01-09 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210109_cleansed
# Processing 2021-01-10 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210110_cleansed
# Processing 2021-01-11 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210111_cleansed
# Processing 2021-01-12 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210112_cleansed
# Processing 2021-01-13 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210113_cleansed
# Processing 2021-01-14 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210114_cleansed
# Processing 2021-01-15 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210115_cleansed
# Processing 2021-01-16 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210116_cleansed
# Processing 2021-01-17 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210117_cleansed
# Processing 2021-01-18 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210118_cleansed
# Processing 2021-01-19 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210119_cleansed
# Processing 2021-01-20 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210120_cleansed
# Processing 2021-01-21 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210121_cleansed
# Processing 2021-01-22 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210122_cleansed
# Processing 2021-01-23 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210123_cleansed
# Processing 2021-01-24 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210124_cleansed
# Processing 2021-01-25 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210125_cleansed
# Processing 2021-01-26 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210126_cleansed
# Processing 2021-01-27 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210127_cleansed
# Processing 2021-01-28 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210128_cleansed
# Processing 2021-01-29 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210129_cleansed
# Processing 2021-01-30 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210130_cleansed
# Processing 2021-01-31 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210131_cleansed
# Processing 2021-02-01 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210201_cleansed
# Processing 2021-02-02 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210202_cleansed
# Processing 2021-02-03 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210203_cleansed
# Processing 2021-02-04 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210204_cleansed
# Processing 2021-02-05 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210205_cleansed
# Processing 2021-02-06 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210206_cleansed
# Processing 2021-02-07 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210207_cleansed
# Processing 2021-02-08 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210208_cleansed
# Processing 2021-02-09 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210209_cleansed
# Processing 2021-02-10 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210210_cleansed
# Processing 2021-02-11 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210211_cleansed
# Processing 2021-02-12 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210212_cleansed
# Processing 2021-02-13 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210213_cleansed
# Processing 2021-02-14 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210214_cleansed
# Processing 2021-02-15 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210215_cleansed
# Processing 2021-02-16 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210216_cleansed
# Processing 2021-02-17 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210217_cleansed
# Processing 2021-02-18 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210218_cleansed
# Processing 2021-02-19 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210219_cleansed
# Processing 2021-02-20 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210220_cleansed
# Processing 2021-02-21 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210221_cleansed
# Processing 2021-02-22 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210222_cleansed
# Processing 2021-02-23 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210223_cleansed
# Processing 2021-02-24 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210224_cleansed
# Processing 2021-02-25 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210225_cleansed
# Processing 2021-02-26 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210226_cleansed
# Processing 2021-02-27 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210227_cleansed
# Processing 2021-02-28 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210228_cleansed
# Processing 2021-03-01 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210301_cleansed
# Processing 2021-03-02 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210302_cleansed
# Processing 2021-03-03 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210303_cleansed
# Processing 2021-03-04 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210304_cleansed
# Processing 2021-03-05 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210305_cleansed
# Processing 2021-03-06 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210306_cleansed
# Processing 2021-03-07 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210307_cleansed
# Processing 2021-03-08 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210308_cleansed
# Processing 2021-03-09 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210309_cleansed
# Processing 2021-03-10 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210310_cleansed
# Processing 2021-03-11 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210311_cleansed
# Processing 2021-03-12 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210312_cleansed
# Processing 2021-03-13 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210313_cleansed
# Processing 2021-03-14 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210314_cleansed
# Processing 2021-03-15 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210315_cleansed
# Processing 2021-03-16 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210316_cleansed
# Processing 2021-03-17 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210317_cleansed
# Processing 2021-03-18 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210318_cleansed
# Processing 2021-03-19 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210319_cleansed
# Processing 2021-03-20 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210320_cleansed
# Processing 2021-03-21 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210321_cleansed
# Processing 2021-03-22 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210322_cleansed
# Processing 2021-03-23 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210323_cleansed
# Processing 2021-03-24 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210324_cleansed
# Processing 2021-03-25 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210325_cleansed
# Processing 2021-03-26 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210326_cleansed
# Processing 2021-03-27 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210327_cleansed
# Processing 2021-03-28 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210328_cleansed
# Processing 2021-03-29 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210329_cleansed
# Processing 2021-03-30 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210330_cleansed
# Processing 2021-03-31 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210331_cleansed
# Processing 2021-04-01 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210401_cleansed
# Processing 2021-04-02 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210402_cleansed
# Processing 2021-04-03 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210403_cleansed
# Processing 2021-04-04 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210404_cleansed
# Processing 2021-04-05 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210405_cleansed
# Processing 2021-04-06 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210406_cleansed
# Processing 2021-04-07 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210407_cleansed
# Processing 2021-04-08 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210408_cleansed
# Processing 2021-04-09 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210409_cleansed
# Processing 2021-04-10 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210410_cleansed
# Processing 2021-04-11 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210411_cleansed
# Processing 2021-04-12 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210412_cleansed
# Processing 2021-04-13 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210413_cleansed
# Processing 2021-04-14 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210414_cleansed
# Processing 2021-04-15 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210415_cleansed
# Processing 2021-04-16 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210416_cleansed
# Processing 2021-04-17 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210417_cleansed
# Processing 2021-04-18 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210418_cleansed
# Processing 2021-04-19 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210419_cleansed
# Processing 2021-04-20 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210420_cleansed
# Processing 2021-04-21 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210421_cleansed
# Processing 2021-04-22 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210422_cleansed
# Processing 2021-04-23 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210423_cleansed
# Processing 2021-04-24 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210424_cleansed
# Processing 2021-04-25 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210425_cleansed
# Processing 2021-04-26 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210426_cleansed
# Processing 2021-04-27 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210427_cleansed
# Processing 2021-04-28 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210428_cleansed
# Processing 2021-04-29 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210429_cleansed
# Processing 2021-04-30 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210430_cleansed
# Processing 2021-05-01 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210501_cleansed
# Processing 2021-05-02 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210502_cleansed
# Processing 2021-05-03 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210503_cleansed
# Processing 2021-05-04 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210504_cleansed
# Processing 2021-05-05 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210505_cleansed
# Processing 2021-05-06 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210506_cleansed
# Processing 2021-05-07 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210507_cleansed
# Processing 2021-05-08 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210508_cleansed
# Processing 2021-05-09 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210509_cleansed
# Processing 2021-05-10 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210510_cleansed
# Processing 2021-05-11 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210511_cleansed
# Processing 2021-05-12 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210512_cleansed
# Processing 2021-05-13 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210513_cleansed
# Processing 2021-05-14 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210514_cleansed
# Processing 2021-05-15 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210515_cleansed
# Processing 2021-05-16 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210516_cleansed
# Processing 2021-05-17 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210517_cleansed
# Processing 2021-05-18 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210518_cleansed
# Processing 2021-05-19 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210519_cleansed
# Processing 2021-05-20 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210520_cleansed
# Processing 2021-05-21 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210521_cleansed
# Processing 2021-05-22 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210522_cleansed
# Processing 2021-05-23 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210523_cleansed
# Processing 2021-05-24 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210524_cleansed
# Processing 2021-05-25 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210525_cleansed
# Processing 2021-05-26 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210526_cleansed
# Processing 2021-05-27 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210527_cleansed
# Processing 2021-05-28 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210528_cleansed
# Processing 2021-05-29 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210529_cleansed
# Processing 2021-05-30 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210530_cleansed
# Processing 2021-05-31 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210531_cleansed
# Processing 2021-06-01 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210601_cleansed
# Processing 2021-06-02 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210602_cleansed
# Processing 2021-06-03 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210603_cleansed
# Processing 2021-06-04 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210604_cleansed
# Processing 2021-06-05 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210605_cleansed
# Processing 2021-06-06 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210606_cleansed
# Processing 2021-06-07 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210607_cleansed
# Processing 2021-06-08 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210608_cleansed
# Processing 2021-06-09 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210609_cleansed
# Processing 2021-06-10 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210610_cleansed
# Processing 2021-06-11 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210611_cleansed
# Processing 2021-06-12 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210612_cleansed
# Processing 2021-06-13 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210613_cleansed
# Processing 2021-06-14 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210614_cleansed
# Processing 2021-06-15 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210615_cleansed
# Processing 2021-06-16 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210616_cleansed
# Processing 2021-06-17 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210617_cleansed
# Processing 2021-06-18 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210618_cleansed
# Processing 2021-06-19 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210619_cleansed
# Processing 2021-06-20 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210620_cleansed
# Processing 2021-06-21 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210621_cleansed
# Processing 2021-06-22 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210622_cleansed
# Processing 2021-06-23 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210623_cleansed
# Processing 2021-06-24 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210624_cleansed
# Processing 2021-06-25 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210625_cleansed
# Processing 2021-06-26 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210626_cleansed
# Processing 2021-06-27 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210627_cleansed
# Processing 2021-06-28 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210628_cleansed
# Processing 2021-06-29 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210629_cleansed
# Processing 2021-06-30 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210630_cleansed
# Processing 2021-07-01 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210701_cleansed
# Processing 2021-07-02 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210702_cleansed
# Processing 2021-07-03 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210703_cleansed
# Processing 2021-07-04 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210704_cleansed
# Processing 2021-07-05 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210705_cleansed
# Processing 2021-07-06 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210706_cleansed
# Processing 2021-07-07 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210707_cleansed
# Processing 2021-07-08 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210708_cleansed
# Processing 2021-07-09 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210709_cleansed
# Processing 2021-07-10 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210710_cleansed
# Processing 2021-07-11 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210711_cleansed
# Processing 2021-07-12 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210712_cleansed
# ...
# Processing 2021-09-15 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210915_cleansed
# Processing 2021-09-16 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210916_cleansed
# Processing 2021-09-17 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210917_cleansed
# Processing 2021-09-18 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210918_cleansed
# Processing 2021-09-19 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210919_cleansed
# Processing 2021-09-20 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210920_cleansed
# Processing 2021-09-21 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210921_cleansed
# Processing 2021-09-22 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210922_cleansed
# Processing 2021-09-23 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210923_cleansed
# Processing 2021-09-24 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210924_cleansed
# Processing 2021-09-25 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210925_cleansed
# Processing 2021-09-26 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210926_cleansed
# Processing 2021-09-27 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210927_cleansed
# Processing 2021-09-28 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210928_cleansed
# Processing 2021-09-29 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210929_cleansed
# Processing 2021-09-30 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20210930_cleansed
# Processing 2021-10-01 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211001_cleansed
# Processing 2021-10-02 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211002_cleansed
# Processing 2021-10-03 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211003_cleansed
# Processing 2021-10-04 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211004_cleansed
# Processing 2021-10-05 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211005_cleansed
# Processing 2021-10-06 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211006_cleansed
# Processing 2021-10-07 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211007_cleansed
# Processing 2021-10-08 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211008_cleansed
# Processing 2021-10-09 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211009_cleansed
# Processing 2021-10-10 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211010_cleansed
# Processing 2021-10-11 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211011_cleansed
# Processing 2021-10-12 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211012_cleansed
# Processing 2021-10-13 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211013_cleansed
# Processing 2021-10-14 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211014_cleansed
# Processing 2021-10-15 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211015_cleansed
# Processing 2021-10-16 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211016_cleansed
# Processing 2021-10-17 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211017_cleansed
# Processing 2021-10-18 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211018_cleansed
# Processing 2021-10-19 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211019_cleansed
# Processing 2021-10-20 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211020_cleansed
# Processing 2021-10-21 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211021_cleansed
# Processing 2021-10-22 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211022_cleansed
# Processing 2021-10-23 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211023_cleansed
# Processing 2021-10-24 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211024_cleansed
# Processing 2021-10-25 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211025_cleansed
# Processing 2021-10-26 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211026_cleansed
# Processing 2021-10-27 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211027_cleansed
# Processing 2021-10-28 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211028_cleansed
# Processing 2021-10-29 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211029_cleansed
# Processing 2021-10-30 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211030_cleansed
# Processing 2021-10-31 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211031_cleansed
# Processing 2021-11-01 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211101_cleansed
# Processing 2021-11-02 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211102_cleansed
# Processing 2021-11-03 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211103_cleansed
# Processing 2021-11-04 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211104_cleansed
# Processing 2021-11-05 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211105_cleansed
# Processing 2021-11-06 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211106_cleansed
# Processing 2021-11-07 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211107_cleansed
# Processing 2021-11-08 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211108_cleansed
# Processing 2021-11-09 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211109_cleansed
# Processing 2021-11-10 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211110_cleansed
# Processing 2021-11-11 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211111_cleansed
# Processing 2021-11-12 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211112_cleansed
# Processing 2021-11-13 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211113_cleansed
# Processing 2021-11-14 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211114_cleansed
# Processing 2021-11-15 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211115_cleansed
# Processing 2021-11-16 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211116_cleansed
# Processing 2021-11-17 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211117_cleansed
# Processing 2021-11-18 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211118_cleansed
# Processing 2021-11-19 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211119_cleansed
# Processing 2021-11-20 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211120_cleansed
# Processing 2021-11-21 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211121_cleansed
# Processing 2021-11-22 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211122_cleansed
# Processing 2021-11-23 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211123_cleansed
# Processing 2021-11-24 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211124_cleansed
# Processing 2021-11-25 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211125_cleansed
# Processing 2021-11-26 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211126_cleansed
# Processing 2021-11-27 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211127_cleansed
# Processing 2021-11-28 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211128_cleansed
# Processing 2021-11-29 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211129_cleansed
# Processing 2021-11-30 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211130_cleansed
# Processing 2021-12-01 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211201_cleansed
# Processing 2021-12-02 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211202_cleansed
# Processing 2021-12-03 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211203_cleansed
# Processing 2021-12-04 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211204_cleansed
# Processing 2021-12-05 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211205_cleansed
# Processing 2021-12-06 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211206_cleansed
# Processing 2021-12-07 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211207_cleansed
# Processing 2021-12-08 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211208_cleansed
# Processing 2021-12-09 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211209_cleansed
# Processing 2021-12-10 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211210_cleansed
# Processing 2021-12-11 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211211_cleansed
# Processing 2021-12-12 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211212_cleansed
# Processing 2021-12-13 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211213_cleansed
# Processing 2021-12-14 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211214_cleansed
# Processing 2021-12-15 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211215_cleansed
# Processing 2021-12-16 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211216_cleansed
# Processing 2021-12-17 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211217_cleansed
# Processing 2021-12-18 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211218_cleansed
# Processing 2021-12-19 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211219_cleansed
# Processing 2021-12-20 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211220_cleansed
# Processing 2021-12-21 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211221_cleansed
# Processing 2021-12-22 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211222_cleansed
# Processing 2021-12-23 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211223_cleansed
# Processing 2021-12-24 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211224_cleansed
# Processing 2021-12-25 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211225_cleansed
# Processing 2021-12-26 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211226_cleansed
# Processing 2021-12-27 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211227_cleansed
# Processing 2021-12-28 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211228_cleansed
# Processing 2021-12-29 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211229_cleansed
# Processing 2021-12-30 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211230_cleansed
# Processing 2021-12-31 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20211231_cleansed
# Processing 2022-01-01 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220101_cleansed
# Processing 2022-01-02 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220102_cleansed
# Processing 2022-01-03 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220103_cleansed
# Processing 2022-01-04 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220104_cleansed
# Processing 2022-01-05 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220105_cleansed
# Processing 2022-01-06 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220106_cleansed
# Processing 2022-01-07 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220107_cleansed
# Processing 2022-01-08 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220108_cleansed
# Processing 2022-01-09 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220109_cleansed
# Processing 2022-01-10 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220110_cleansed
# Processing 2022-01-11 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220111_cleansed
# Processing 2022-01-12 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220112_cleansed
# Processing 2022-01-13 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220113_cleansed
# Processing 2022-01-14 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220114_cleansed
# Processing 2022-01-15 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220115_cleansed
# Processing 2022-01-16 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220116_cleansed
# Processing 2022-01-17 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220117_cleansed
# Processing 2022-01-18 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220118_cleansed
# Processing 2022-01-19 00:00:00  ...
# Processing 2022-01-20 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220120_cleansed
# Processing 2022-01-21 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220121_cleansed
# Processing 2022-01-22 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220122_cleansed
# Processing 2022-01-23 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220123_cleansed
# Processing 2022-01-24 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220124_cleansed
# Processing 2022-01-25 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220125_cleansed
# Processing 2022-01-26 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220126_cleansed
# Processing 2022-01-27 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220127_cleansed
# Processing 2022-01-28 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220128_cleansed
# Processing 2022-01-29 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220129_cleansed
# Processing 2022-01-30 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220130_cleansed
# Processing 2022-01-31 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220131_cleansed
# Processing 2022-02-01 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220201_cleansed
# Processing 2022-02-02 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220202_cleansed
# Processing 2022-02-03 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220203_cleansed
# Processing 2022-02-04 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220204_cleansed
# Processing 2022-02-05 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220205_cleansed
# Processing 2022-02-06 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220206_cleansed
# Processing 2022-02-07 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220207_cleansed
# Processing 2022-02-08 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220208_cleansed
# Processing 2022-02-09 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220209_cleansed
# Processing 2022-02-10 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220210_cleansed
# Processing 2022-02-11 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220211_cleansed
# Processing 2022-02-12 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220212_cleansed
# Processing 2022-02-13 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220213_cleansed
# Processing 2022-02-14 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220214_cleansed
# Processing 2022-02-15 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220215_cleansed
# Processing 2022-02-16 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220216_cleansed
# Processing 2022-02-17 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220217_cleansed
# Processing 2022-02-18 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220218_cleansed
# Processing 2022-02-19 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220219_cleansed
# Processing 2022-02-20 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220220_cleansed
# Processing 2022-02-21 00:00:00  ... cached: raw/enhanced_sur_covid_19_chi.csv_20220221_cleansed
# Processing 2022-02-22 00:00:00  ...
# Processing 2022-02-23 00:00:00  ...
# Processing 2022-02-24 00:00:00  ...
# Processing 2022-02-25 00:00:00  ...
# Processing 2022-02-26 00:00:00  ...
# Processing 2022-02-27 00:00:00  ...
# Processing 2022-02-28 00:00:00  ...
# Processing 2022-03-01 00:00:00  ...
# Processing 2022-03-02 00:00:00  ...
# Processing 2022-03-03 00:00:00  ...
# Processing 2022-03-04 00:00:00  ...
# Processing 2022-03-05 00:00:00  ...
# Processing 2022-03-06 00:00:00  ...
# Processing 2022-03-07 00:00:00  ...
# Processing 2022-03-08 00:00:00  ...
# Processing 2022-03-09 00:00:00  ...
# Processing 2022-03-10 00:00:00  ...
# Processing 2022-03-11 00:00:00  ...
# Processing 2022-03-12 00:00:00  ...

# %% [markdown]
# ### STEP3: Combine the timeline of each patient

# %% [markdown]
# <Strong>Again this part takes time</Strong>

# %%
def merge_history(history):
    H = history
    case_ids = H['個案編號'].unique()
    extra_cols = ['待入院|有待提供@日期', '住院@日期', '出院@日期','死亡@日期','不適用|nan@日期']

    df_merged = pd.DataFrame()
    for i, case_id in enumerate(case_ids):
        if i % 1000 == 0:
            print(f"Merging the {i}th case ...")
        patient = H[H['個案編號'] == case_id]
        pending_date = patient[(patient['住院/出院/死亡'] == '待入院') | (patient['住院/出院/死亡'] == '有待提供')].record_date.min()
        enter_date = patient[patient['住院/出院/死亡'] == '住院'].record_date.min()
        exit_date = patient[patient['住院/出院/死亡'] == '出院'].record_date.min()
        pass_date = patient[patient['住院/出院/死亡'] == '死亡'].record_date.min()
        #na_date = patient[(patient['住院/出院/死亡'] == '不適用') | (patient['住院/出院/死亡'].isnull()) ].record_date.min()

        latest = patient[-1:].copy()
        latest['待入院|有待提供@日期'] = pending_date
        latest['住院@日期'] = enter_date
        latest['出院@日期'] = exit_date
        latest['死亡@日期'] = pass_date
        #latest['不適用|nan@日期'] = na_date

        try:
            latest['輪候日數'] = latest['住院@日期'] - latest['待入院|有待提供@日期']
        except:
            latest['輪候日數'] = np.NaN

        try:
            latest['住院日數'] = latest['出院@日期'] - latest['住院@日期']
        except:
            latest['住院日數'] = np.NaN
        df_merged = df_merged.append(latest)

    # Convert dt to days
    df_merged['輪候日數'] = df_merged['輪候日數'].dt.days
    df_merged['住院日數'] = df_merged['住院日數'].dt.days
    return df_merged

df_merged = merge_history(history)
# Out:
# Merging the 0th case ...
# Merging the 1000th case ...
# Merging the 2000th case ...
# Merging the 3000th case ...
# Merging the 4000th case ...
# Merging the 5000th case ...
# Merging the 6000th case ...
# Merging the 7000th case ...
# Merging the 8000th case ...
# Merging the 9000th case ...
# Merging the 10000th case ...
# Merging the 11000th case ...
# Merging the 12000th case ...
# Merging the 13000th case ...
# Merging the 14000th case ...
# Merging the 15000th case ...

# %% [markdown]
# ### STEP4: Add age, year, month and week bins

# %%
def cut_bins(df_merged):
    # Age Bins
    bins_age = [0,2,5,11,18,25,35,45,55,65,75,85,150]
    bins_age_label = ['0-1 歲','2-4 歲','5-10 歲','11-17 歲','18-24 歲','25-34 歲',
            '35-44 歲','45-54 歲','55-64 歲','65-74 歲','75-84 歲','85 歲以上']

    # Time Bins
    tz= None #"Asia/Hong_Kong" #Not needed
    YEARS = [year for year in pd.date_range(DAY_1, DAY_N, freq='YS', tz=tz)]
    bins_year = [np.datetime64(d) for d in YEARS]
    bins_year_label = [ d.year for d in YEARS[:-1]]

    MONTHS = [month for month in pd.date_range(DAY_1, DAY_N, freq='MS', tz=tz)]
    bins_month = [np.datetime64(d) for d in MONTHS]
    bins_month_label = [ f'{d.month}/{d.year}' for d in MONTHS[:-1]]

    WEEKS = [week for week in pd.date_range(DAY_1, DAY_N, freq='W-SUN', tz=tz)]
    bins_week = [np.datetime64(d) for d in WEEKS]
    bins_week_label = [ f'{d.day}/{d.month}/{d.year}' for d in WEEKS[:-1]]

    df = df_merged.copy()
    df['年齡組別'] = pd.cut(df['年齡'], bins=bins_age, labels=bins_age_label, right=False)
    df['年'] = pd.cut(df['報告日期'], bins=bins_year, labels=bins_year_label, right=False)
    df['月'] = pd.cut(df['報告日期'], bins=bins_month, labels=bins_month_label, right=False)
    df['週'] = pd.cut(df['報告日期'], bins=bins_week, labels=bins_week_label, right=False)
    return df

df = cut_bins(df_merged)

# %% [markdown]
# Lets save the result after all these long program run:

# %%
df.to_pickle("df.pickle")
df = pd.read_pickle("df.pickle")

# %% [markdown]
# ### Group by age group 以年齡組別分類

# %%
# Analyze Period
start_date = np.datetime64(datetime.date(2020,1,1))
end_date = np.datetime64(datetime.date(2022,10,1))
pd.set_option('display.max_rows', 4000)

# Query
groups = df[
    (
        (df['住院/出院/死亡'] == '出院')|
        (df['住院/出院/死亡'] == '死亡')|
        (df['住院/出院/死亡'] == '住院')|
        (df['住院/出院/死亡'] == '待入院')
    )&
    (df['報告日期'] >= start_date) &
    (df['報告日期'] <= end_date)
].groupby(
    ['年', '年齡組別']
).agg({
    '性別': ['count'],
    '輪候日數': ['mean'],
    '住院日數': ['mean', 'sum']
}).round(1).replace(np.NaN, '-')

g = groups[
    groups['性別']['count'] > 0
]
display(g)
# Out:
#                 性別 輪候日數  住院日數
#              count mean  mean      sum
# 年    年齡組別
# 2020 0-1 歲      61  1.0  11.2    638.0
#      2-4 歲     109  1.2  10.8   1167.0
#      5-10 歲    188  1.2  10.5   1947.0
#      11-17 歲   305  1.2  11.7   3490.0
#      18-24 歲   800  1.4  11.5   8748.0
#      25-34 歲  1340  1.3  10.9  14021.0
#      35-44 歲  1439  1.3  11.1  15221.0
#      45-54 歲  1413  1.3  11.3  15482.0
#      55-64 歲  1582  1.2  13.9  20946.0
#      65-74 歲   999  1.1  18.3  17155.0
#      75-84 歲   387  1.1  24.4   7569.0
#      85 歲以上    194  1.0  27.5   3632.0
# 2021 0-1 歲      75  1.0  12.6    921.0
#      2-4 歲      67  1.0  11.4    766.0
#      5-10 歲    100  1.0  11.7   1156.0
#      11-17 歲   136  1.0  12.4   1649.0
#      18-24 歲   304  1.0  11.5   3493.0
#      25-34 歲   847  1.0  11.0   8981.0
#      35-44 歲   888  1.0  10.3   8910.0
#      45-54 歲   543  1.0  12.5   6600.0
#      55-64 歲   433  1.0  12.5   5323.0
#      65-74 歲   259  1.0  16.8   4196.0
#      75-84 歲   108  1.0  22.0   2130.0
#      85 歲以上     37  1.0  28.4    738.0
# 2022 0-1 歲      38  1.2  16.1    242.0
#      2-4 歲      54  1.4  12.1    291.0
#      5-10 歲    125  1.4  10.5    703.0
#      11-17 歲   185  1.3  11.1   1419.0
#      18-24 歲   263  1.4  10.5   2263.0
#      25-34 歲   482  1.5  10.5   3595.0
#      35-44 歲   507  1.6  10.1   3222.0
#      45-54 歲   476  1.5  11.2   3165.0
#      55-64 歲   355  1.4  12.3   1853.0
#      65-74 歲   186  1.4  12.6    996.0
#      75-84 歲    80  1.0  12.7    317.0
#      85 歲以上     27  1.5  18.5     74.0

# %% [markdown]
# ### Group by year  以每年計

# %%
# Analyze Period
start_date = np.datetime64(datetime.date(2020,1,1))
end_date = np.datetime64(datetime.date(2022,10,1))

# Query
groups = df[
    (
        (df['住院/出院/死亡'] == '出院')|
        (df['住院/出院/死亡'] == '死亡')|
        (df['住院/出院/死亡'] == '住院')|
        (df['住院/出院/死亡'] == '待入院')
    )&
    (df['報告日期'] >= start_date) &
    (df['報告日期'] <= end_date)
].groupby(
    ['年','月']
).agg({
    '性別': ['count'],
    '輪候日數': ['mean'],
    '住院日數': ['mean', 'sum']
}).round(1).replace(np.NaN, '-')


pd.set_option('display.max_rows', 4000)
g = groups[
    groups['性別']['count'] > 0
]
display(g)
# Out:
#                 性別 輪候日數  住院日數
#              count mean  mean      sum
# 年    月
# 2020 1/2020     13    -     -      0.0
#      2/2020     82    -  30.3     91.0
#      3/2020    620    -  17.6   9395.0
#      4/2020    323  1.0  17.1   5517.0
#      5/2020     47  1.0  19.0    893.0
#      6/2020    121  1.0  14.4   1699.0
#      7/2020   2040  1.8  12.7  24847.0
#      8/2020   1537  1.3  12.0  17868.0
#      9/2020    277  1.0  12.8   3313.0
#      10/2020   234  1.0  11.4   2401.0
#      11/2020   991  1.0  12.7  12103.0
#      12/2020  2532  1.0  13.1  31889.0
# 2021 1/2021   1605  1.0  12.5  19350.0
#      2/2021    553  1.0  10.3   5428.0
#      3/2021    459  1.0  10.7   4775.0
#      4/2021    305  1.0  10.9   3193.0
#      5/2021     67  1.0   6.6    430.0
#      6/2021     79  1.0  11.7    915.0
#      7/2021     61  1.5  10.6    644.0
#      8/2021    126  1.0  11.4   1431.0
#      9/2021    110  1.0   9.5   1040.0
#      10/2021   129  1.0  13.6   1754.0
#      11/2021    90  1.0  17.8   1606.0
#      12/2021   213  1.0  20.4   4297.0
# 2022 1/2022   1554  1.3  12.5  16660.0
#      2/2022   1225  1.7   4.6   1480.0

# %% [markdown]
# ### Group by week 以每週計

# %%
# Analyze Period
start_date = np.datetime64(datetime.date(2020,1,1))
end_date = np.datetime64(datetime.date(2022,10,1))

# Query
groups = df[
    (
        (df['住院/出院/死亡'] == '出院')|
        (df['住院/出院/死亡'] == '死亡')|
        (df['住院/出院/死亡'] == '住院')|
        (df['住院/出院/死亡'] == '待入院')
    )&
    (df['報告日期'] >= start_date) &
    (df['報告日期'] <= end_date)
].groupby(
    ['月', '週']
).agg({
    '性別': ['count'],
    '輪候日數': ['mean'],
    '住院日數': ['mean', 'sum']
}).round(1).replace(np.NaN, '-')


pd.set_option('display.max_rows', 4000)
g = groups[
    groups['性別']['count'] > 0
]
display(g)
# Out:
#                       性別 輪候日數  住院日數
#                    count mean  mean     sum
# 月       週
# 1/2020  19/1/2020      5    -     -     0.0
#         26/1/2020      8    -     -     0.0
# 2/2020  26/1/2020      2    -     -     0.0
#         2/2/2020      11    -     -     0.0
#         9/2/2020      30    -  29.5    59.0
#         16/2/2020     14    -  32.0    32.0
#         23/2/2020     25    -     -     0.0
# 3/2020  1/3/2020      15    -  41.7   125.0
#         8/3/2020      32    -  19.7   296.0
#         15/3/2020    132    -  13.4  1423.0
#         22/3/2020    309    -  17.8  5010.0
#         29/3/2020    132    -  19.9  2541.0
# 4/2020  29/3/2020    148  1.0  18.3  2713.0
#         5/4/2020     138  1.0  16.5  2280.0
#         12/4/2020     23  1.0  15.0   344.0
#         19/4/2020     14    -  12.9   180.0
# 5/2020  26/4/2020      2    -  16.0    32.0
#         3/5/2020       5    -  18.2    91.0
#         10/5/2020      8  1.0  14.9   119.0
#         17/5/2020     13    -  18.8   244.0
#         24/5/2020     17    -  20.1   341.0
#         31/5/2020      2    -  33.0    66.0
# 6/2020  31/5/2020     21  1.0  17.5   333.0
#         7/6/2020       4    -  16.0    64.0
#         14/6/2020     19  1.0  14.7   279.0
#         21/6/2020     69  1.0  13.3   903.0
#         28/6/2020      8  1.0  15.0   120.0
# 7/2020  28/6/2020     53  1.0  12.8   677.0
#         5/7/2020     168  1.0  18.3  2907.0
#         12/7/2020    344  1.5  16.9  5591.0
#         19/7/2020    719  1.5  12.6  8845.0
#         26/7/2020    756  2.1   9.5  6827.0
# 8/2020  26/7/2020    125  1.6  10.3  1244.0
#         2/8/2020     611  1.5  11.2  6529.0
#         9/8/2020     398  1.1  12.5  4849.0
#         16/8/2020    251  1.0  13.0  3202.0
#         23/8/2020    128  1.0  13.8  1683.0
#         30/8/2020     24  1.0  15.7   361.0
# 9/2020  30/8/2020     47  1.0  12.6   518.0
#         6/9/2020      81  1.0  12.5   951.0
#         13/9/2020     71  1.0  15.0  1032.0
#         20/9/2020     50  1.0  11.0   539.0
#         27/9/2020     28  1.0  11.4   273.0
# 10/2020 27/9/2020     21  1.0   9.8   197.0
#         4/10/2020     67  1.0  14.0   843.0
#         11/10/2020    62  1.0   9.4   543.0
#         18/10/2020    50  1.0  11.3   488.0
#         25/10/2020    34  1.0  11.0   330.0
# 11/2020 1/11/2020     41  1.0  10.5   367.0
#         8/11/2020     80  1.0  10.5   770.0
#         15/11/2020   116  1.0  12.8  1397.0
#         22/11/2020   563  1.0  12.9  7126.0
#         29/11/2020   191  1.0  13.1  2443.0
# 12/2020 29/11/2020   488  1.0  15.4  7345.0
#         6/12/2020    644  1.0  12.8  7947.0
#         13/12/2020   632  1.0  13.1  7950.0
#         20/12/2020   462  1.0  11.6  5062.0
#         27/12/2020   306  1.0  12.2  3585.0
# 1/2021  27/12/2020    77  1.0  12.1   882.0
#         3/1/2021     288  1.0  12.3  3346.0
#         10/1/2021    290  1.0  11.6  3226.0
#         17/1/2021    507  1.0  14.1  6938.0
#         24/1/2021    390  1.0  11.7  4407.0
#         31/1/2021     53  1.0  10.6   551.0
# 2/2021  31/1/2021    156  1.0  10.3  1547.0
#         7/2/2021     159  1.0  10.1  1558.0
#         14/2/2021     81  1.0   8.4   608.0
#         21/2/2021    135  1.0  11.4  1494.0
#         28/2/2021     22  1.0  10.5   221.0
# 3/2021  28/2/2021     69  1.0  10.7   727.0
#         7/3/2021     182  1.0  11.2  2021.0
#         14/3/2021    112  1.0  10.5  1147.0
#         21/3/2021     74  1.0   9.8   656.0
#         28/3/2021     22  1.0  10.7   224.0
# 4/2021  28/3/2021     34  1.0  10.5   336.0
#         4/4/2021      67  1.0  11.4   738.0
#         11/4/2021     85  1.0  10.3   835.0
#         18/4/2021     75  1.0   9.9   732.0
#         25/4/2021     44  1.0  13.1   552.0
# 5/2021  25/4/2021      8  1.0   4.8    38.0
#         2/5/2021      23  1.0   8.3   190.0
#         9/5/2021      15  1.0   6.6    99.0
#         16/5/2021     10  1.0   3.8    34.0
#         23/5/2021      7  1.0   8.1    57.0
#         30/5/2021      4  1.0   4.0    12.0
# 6/2021  30/5/2021     10  1.1   9.9    99.0
#         6/6/2021      26  1.0  10.3   269.0
#         13/6/2021      7  1.0   7.1    50.0
#         20/6/2021     24  1.0  13.7   316.0
#         27/6/2021     12  1.0  15.1   181.0
# 7/2021  27/6/2021     16  1.0  13.4   214.0
#         4/7/2021      11  1.0   9.7   107.0
#         11/7/2021      6  1.0  12.8    77.0
#         18/7/2021     19  1.0   9.1   173.0
#         25/7/2021      9  4.6   8.1    73.0
# 8/2021  1/8/2021      27  1.0   9.6   260.0
#         8/8/2021      20  1.0  12.4   247.0
#         15/8/2021     19  1.0  10.6   201.0
#         22/8/2021     48  1.0  12.5   598.0
#         29/8/2021     12  1.0  10.4   125.0
# 9/2021  29/8/2021      6  1.0   8.5    51.0
#         5/9/2021      29  1.0   9.7   281.0
#         12/9/2021     15  1.0   9.2   138.0
#         19/9/2021     28  1.0   9.1   254.0
#         26/9/2021     32  1.0   9.9   316.0
# 10/2021 26/9/2021      9  1.0   9.0    81.0
#         3/10/2021     35  1.0   9.1   318.0
#         10/10/2021    30  1.0  12.2   365.0
#         17/10/2021    28  1.0  18.5   518.0
#         24/10/2021    26  1.0  17.7   461.0
#         31/10/2021     1  1.0  11.0    11.0
# 11/2021 31/10/2021    21  1.0  14.9   313.0
#         7/11/2021     13  1.0  12.4   161.0
#         14/11/2021    19  1.0  15.9   302.0
#         21/11/2021    25  1.0  22.7   567.0
#         28/11/2021    12  1.0  21.9   263.0
# 12/2021 28/11/2021    16  1.0  20.3   325.0
#         5/12/2021     31  1.1  24.5   761.0
#         12/12/2021    35  1.0  22.0   748.0
#         19/12/2021    62  1.0  19.7  1222.0
#         26/12/2021    69  1.0  18.2  1241.0
# 1/2022  26/12/2021    17  1.0  17.5   297.0
#         2/1/2022     235  1.0  15.6  3658.0
#         9/1/2022     129  1.0  15.2  1940.0
#         16/1/2022    115  1.0  14.6  1667.0
#         23/1/2022    883  1.4  11.2  8222.0
#         30/1/2022    175  1.5   8.5   876.0
# 2/2022  30/1/2022    875  1.4   5.0  1387.0
#         6/2/2022     350  2.7   2.2    93.0
